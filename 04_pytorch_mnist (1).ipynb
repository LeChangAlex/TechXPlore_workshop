# %% [markdown]
# [![AnalyticsDojo](https://github.com/rpi-techfundamentals/fall2018-materials/blob/master/fig/final-logo.png?raw=1)](http://rpi.analyticsdojo.com)
# <center><h1>Pytorch with the MNIST Dataset - MINST</h1></center>
# <center><h3><a href = 'http://rpi.analyticsdojo.com'>rpi.analyticsdojo.com</a></h3></center>
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rpi-techfundamentals/fall2018-materials/blob/master/10-deep-learning/04-pytorch-mnist.ipynb)

# %% [markdown]
# From Kaggle:
# "MNIST ("Modified National Institute of Standards and Technology") is the de facto “hello world” dataset of computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms. As new machine learning techniques emerge, MNIST remains a reliable resource for researchers and learners alike."
#
# [Read more.](https://www.kaggle.com/c/digit-recognizer)
#
#
# <a title="By Josef Steppan [CC BY-SA 4.0 (https://creativecommons.org/licenses/by-sa/4.0)], from Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:MnistExamples.png"><img width="512" alt="MnistExamples" src="https://upload.wikimedia.org/wikipedia/commons/2/27/MnistExamples.png"/></a>

# %% [markdown]
# This code is adopted from the pytorch examples repository.
# It is licensed under BSD 3-Clause "New" or "Revised" License.
# Source: https://github.com/pytorch/examples/
# LICENSE: https://github.com/pytorch/examples/blob/master/LICENSE
#
# ![](https://github.com/rpi-techfundamentals/fall2018-materials/blob/master/10-deep-learning/mnist-comparison.png?raw=1)
# Table from [Wikipedia](https://en.wikipedia.org/wiki/MNIST_database)

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (6.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.12.0)

# %% [markdown]
# ### Pytorch Advantages vs Tensorflow
# - Pytorch Enables dynamic computational graphs (which change be changed) while Tensorflow is static.
# - Tensorflow enables easier deployment.

# %%
#Import Libraries


from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %%
args={}
kwargs={}
args['batch_size']=1000
args['test_batch_size']=1000
args['epochs']=10  #The number of Epochs is the number of times you go through the full dataset. 
args['lr']=0.01 #Learning rate is how fast it will decend. 
args['momentum']=0.5 #SGD momentum (default: 0.5) Momentum is a moving average of our gradients (helps to keep direction).

args['seed']=1 #random seed
args['log_interval']=10
args['cuda']=False

# %%
#load the data
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args['batch_size'], shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args['test_batch_size'], shuffle=True, **kwargs)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Processing...
# Done!

# %%
class Net(nn.Module):
    #This defines the structure of the NN.
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()  #Dropout
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #Convolutional Layer/Pooling Layer/Activation
        x = F.relu(F.max_pool2d(self.conv1(x), 2)) 
        #Convolutional Layer/Dropout/Pooling Layer/Activation
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        #Fully Connected Layer/Activation
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        #Fully Connected Layer/Activation
        x = self.fc2(x)
        #Softmax gets probabilities. 
        return F.log_softmax(x, dim=1)

# %%
def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if args['cuda']:
            data, target = data.cuda(), target.cuda()
        #Variables in Pytorch are differenciable. 
        data, target = Variable(data), Variable(target)
        #This will zero out the gradients for this batch. 
        optimizer.zero_grad()
        output = model(data)
        # Calculate the loss The negative log likelihood loss. It is useful to train a classification problem with C classes.
        loss = F.nll_loss(output, target)
        #dloss/dx for every Variable 
        loss.backward()
        #to do a one-step update on our parameter.
        optimizer.step()
        #Print out the loss periodically. 
        if batch_idx % args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

        test()


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        if args['cuda']:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        test_loss += F.nll_loss(output, target, size_average=False).item() # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(target.data.view_as(pred)).long().cpu().sum()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
model = Net()
if args['cuda']:
    model.cuda()

optimizer = optim.SGD(model.parameters(), lr=args['lr'], momentum=args['momentum'])

for epoch in range(1, args['epochs'] + 1):
    train(epoch)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.335367
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Average loss: 2.3117, Accuracy: 743/10000 (7%)
#
#
# Test set: Average loss: 2.3090, Accuracy: 805/10000 (8%)
#
#
# Test set: Average loss: 2.3058, Accuracy: 909/10000 (9%)
#
#
# Test set: Average loss: 2.3024, Accuracy: 988/10000 (10%)
#
#
# Test set: Average loss: 2.2990, Accuracy: 1106/10000 (11%)
#
#
# Test set: Average loss: 2.2958, Accuracy: 1218/10000 (12%)
#
#
# Test set: Average loss: 2.2926, Accuracy: 1356/10000 (14%)
#
#
# Test set: Average loss: 2.2896, Accuracy: 1457/10000 (15%)
#
#
# Test set: Average loss: 2.2867, Accuracy: 1562/10000 (16%)
#
#
# Test set: Average loss: 2.2837, Accuracy: 1682/10000 (17%)
#
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 2.285747
#
# Test set: Average loss: 2.2808, Accuracy: 1782/10000 (18%)
#
#
# Test set: Average loss: 2.2780, Accuracy: 1881/10000 (19%)
#
#
# Test set: Average loss: 2.2752, Accuracy: 2004/10000 (20%)
#
#
# Test set: Average loss: 2.2722, Accuracy: 2137/10000 (21%)
#
#
# Test set: Average loss: 2.2693, Accuracy: 2245/10000 (22%)
#
#
# Test set: Average loss: 2.2665, Accuracy: 2316/10000 (23%)
#
#
# Test set: Average loss: 2.2636, Accuracy: 2395/10000 (24%)
#
#
# Test set: Average loss: 2.2606, Accuracy: 2525/10000 (25%)
#
#
# Test set: Average loss: 2.2575, Accuracy: 2585/10000 (26%)
#
#
# Test set: Average loss: 2.2544, Accuracy: 2624/10000 (26%)
#
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 2.251784
#
# Test set: Average loss: 2.2513, Accuracy: 2642/10000 (26%)
#
#
# Test set: Average loss: 2.2481, Accuracy: 2640/10000 (26%)
#
#
# Test set: Average loss: 2.2449, Accuracy: 2664/10000 (27%)
#
#
# Test set: Average loss: 2.2415, Accuracy: 2721/10000 (27%)
#
#
# Test set: Average loss: 2.2381, Accuracy: 2822/10000 (28%)
#
#
# Test set: Average loss: 2.2346, Accuracy: 2909/10000 (29%)
#
#
# Test set: Average loss: 2.2310, Accuracy: 3053/10000 (31%)
#
#
# Test set: Average loss: 2.2272, Accuracy: 3168/10000 (32%)
#
#
# Test set: Average loss: 2.2234, Accuracy: 3253/10000 (33%)
#
#
# Test set: Average loss: 2.2195, Accuracy: 3219/10000 (32%)
#
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 2.226115
#
# Test set: Average loss: 2.2154, Accuracy: 3301/10000 (33%)
#
#
# Test set: Average loss: 2.2112, Accuracy: 3413/10000 (34%)
#
#
# Test set: Average loss: 2.2066, Accuracy: 3539/10000 (35%)
#
#
# Test set: Average loss: 2.2020, Accuracy: 3703/10000 (37%)
#
#
# Test set: Average loss: 2.1970, Accuracy: 3811/10000 (38%)
#
#
# Test set: Average loss: 2.1919, Accuracy: 4011/10000 (40%)
#
#
# Test set: Average loss: 2.1867, Accuracy: 4122/10000 (41%)
#
#
# Test set: Average loss: 2.1813, Accuracy: 4242/10000 (42%)
#
#
# Test set: Average loss: 2.1756, Accuracy: 4479/10000 (45%)
#
#
# Test set: Average loss: 2.1697, Accuracy: 4626/10000 (46%)
#
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 2.172033
#
# Test set: Average loss: 2.1636, Accuracy: 4703/10000 (47%)
#
#
# Test set: Average loss: 2.1571, Accuracy: 4649/10000 (46%)
#
#
# Test set: Average loss: 2.1504, Accuracy: 4598/10000 (46%)
#
#
# Test set: Average loss: 2.1434, Accuracy: 4656/10000 (47%)
#
#
# Test set: Average loss: 2.1358, Accuracy: 4819/10000 (48%)
#
#
# Test set: Average loss: 2.1280, Accuracy: 4930/10000 (49%)
#
#
# Test set: Average loss: 2.1199, Accuracy: 5096/10000 (51%)
#
#
# Test set: Average loss: 2.1114, Accuracy: 5368/10000 (54%)
#
#
# Test set: Average loss: 2.1023, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 2.0927, Accuracy: 5670/10000 (57%)
#
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 2.090359
#
# Test set: Average loss: 2.0825, Accuracy: 5822/10000 (58%)
#
#
# Test set: Average loss: 2.0718, Accuracy: 5888/10000 (59%)
#
#
# Test set: Average loss: 2.0606, Accuracy: 5890/10000 (59%)
#
#
# Test set: Average loss: 2.0487, Accuracy: 5928/10000 (59%)
#
#
# Test set: Average loss: 2.0363, Accuracy: 6118/10000 (61%)
#
#
# Test set: Average loss: 2.0231, Accuracy: 6315/10000 (63%)
#
#
# Test set: Average loss: 2.0092, Accuracy: 6432/10000 (64%)
#
#
# Test set: Average loss: 1.9948, Accuracy: 6507/10000 (65%)
#
#
# Test set: Average loss: 1.9793, Accuracy: 6638/10000 (66%)
#
#
# Test set: Average loss: 1.9630, Accuracy: 6839/10000 (68%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.157652
#
# Test set: Average loss: 1.9520, Accuracy: 7071/10000 (71%)
#
#
# Test set: Average loss: 1.9373, Accuracy: 7062/10000 (71%)
#
#
# Test set: Average loss: 1.9205, Accuracy: 7068/10000 (71%)
#
#
# Test set: Average loss: 1.9018, Accuracy: 7045/10000 (70%)
#
#
# Test set: Average loss: 1.8814, Accuracy: 7038/10000 (70%)
#
#
# Test set: Average loss: 1.8599, Accuracy: 7093/10000 (71%)
#
#
# Test set: Average loss: 1.8374, Accuracy: 7126/10000 (71%)
#
#
# Test set: Average loss: 1.8134, Accuracy: 7157/10000 (72%)
#
#
# Test set: Average loss: 1.7881, Accuracy: 7141/10000 (71%)
#
#
# Test set: Average loss: 1.7618, Accuracy: 7212/10000 (72%)
#
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 1.770595
#
# Test set: Average loss: 1.7340, Accuracy: 7277/10000 (73%)
#
#
# Test set: Average loss: 1.7053, Accuracy: 7235/10000 (72%)
#
#
# Test set: Average loss: 1.6749, Accuracy: 7162/10000 (72%)
#
#
# Test set: Average loss: 1.6435, Accuracy: 7172/10000 (72%)
#
#
# Test set: Average loss: 1.6107, Accuracy: 7170/10000 (72%)
#
#
# Test set: Average loss: 1.5764, Accuracy: 7226/10000 (72%)
#
#
# Test set: Average loss: 1.5417, Accuracy: 7280/10000 (73%)
#
#
# Test set: Average loss: 1.5052, Accuracy: 7343/10000 (73%)
#
#
# Test set: Average loss: 1.4677, Accuracy: 7382/10000 (74%)
#
#
# Test set: Average loss: 1.4298, Accuracy: 7501/10000 (75%)
#
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 1.451159
#
# Test set: Average loss: 1.3917, Accuracy: 7614/10000 (76%)
#
#
# Test set: Average loss: 1.3541, Accuracy: 7694/10000 (77%)
#
#
# Test set: Average loss: 1.3165, Accuracy: 7765/10000 (78%)
#
#
# Test set: Average loss: 1.2787, Accuracy: 7818/10000 (78%)
#
#
# Test set: Average loss: 1.2384, Accuracy: 7823/10000 (78%)
#
#
# Test set: Average loss: 1.1996, Accuracy: 7884/10000 (79%)
#
#
# Test set: Average loss: 1.1626, Accuracy: 7917/10000 (79%)
#
#
# Test set: Average loss: 1.1258, Accuracy: 7958/10000 (80%)
#
#
# Test set: Average loss: 1.0905, Accuracy: 7929/10000 (79%)
#
#
# Test set: Average loss: 1.0573, Accuracy: 7931/10000 (79%)
#
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 1.067630
#
# Test set: Average loss: 1.0246, Accuracy: 7977/10000 (80%)
#
#
# Test set: Average loss: 0.9889, Accuracy: 8098/10000 (81%)
#
#
# Test set: Average loss: 0.9574, Accuracy: 8089/10000 (81%)
#
#
# Test set: Average loss: 0.9296, Accuracy: 8099/10000 (81%)
#
#
# Test set: Average loss: 0.9009, Accuracy: 8110/10000 (81%)
#
#
# Test set: Average loss: 0.8751, Accuracy: 8089/10000 (81%)
#
#
# Test set: Average loss: 0.8486, Accuracy: 8141/10000 (81%)
#
#
# Test set: Average loss: 0.8234, Accuracy: 8172/10000 (82%)
#
#
# Test set: Average loss: 0.7999, Accuracy: 8193/10000 (82%)
#
#
# Test set: Average loss: 0.7779, Accuracy: 8256/10000 (83%)
#
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.835112
#
# Test set: Average loss: 0.7589, Accuracy: 8265/10000 (83%)
#
#
# Test set: Average loss: 0.7387, Accuracy: 8332/10000 (83%)
#
#
# Test set: Average loss: 0.7216, Accuracy: 8337/10000 (83%)
#
#
# Test set: Average loss: 0.7060, Accuracy: 8343/10000 (83%)
#
#
# Test set: Average loss: 0.6894, Accuracy: 8334/10000 (83%)
#
#
# Test set: Average loss: 0.6764, Accuracy: 8355/10000 (84%)
#
#
# Test set: Average loss: 0.6598, Accuracy: 8413/10000 (84%)
#
#
# Test set: Average loss: 0.6480, Accuracy: 8368/10000 (84%)
#
#
# Test set: Average loss: 0.6358, Accuracy: 8435/10000 (84%)
#
#
# Test set: Average loss: 0.6233, Accuracy: 8417/10000 (84%)
#
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.609660
#
# Test set: Average loss: 0.6112, Accuracy: 8463/10000 (85%)
#
#
# Test set: Average loss: 0.6028, Accuracy: 8487/10000 (85%)
#
#
# Test set: Average loss: 0.5896, Accuracy: 8512/10000 (85%)
#
#
# Test set: Average loss: 0.5796, Accuracy: 8510/10000 (85%)
#
#
# Test set: Average loss: 0.5724, Accuracy: 8529/10000 (85%)
#
#
# Test set: Average loss: 0.5645, Accuracy: 8523/10000 (85%)
#
#
# Test set: Average loss: 0.5560, Accuracy: 8492/10000 (85%)
#
#
# Test set: Average loss: 0.5460, Accuracy: 8534/10000 (85%)
#
#
# Test set: Average loss: 0.5435, Accuracy: 8568/10000 (86%)
#
#
# Test set: Average loss: 0.5351, Accuracy: 8569/10000 (86%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.916197
#
# Test set: Average loss: 0.5589, Accuracy: 8523/10000 (85%)
#
#
# Test set: Average loss: 0.5623, Accuracy: 8557/10000 (86%)
#
#
# Test set: Average loss: 0.5520, Accuracy: 8613/10000 (86%)
#
#
# Test set: Average loss: 0.5502, Accuracy: 8587/10000 (86%)
#
#
# Test set: Average loss: 0.5482, Accuracy: 8559/10000 (86%)
#
#
# Test set: Average loss: 0.5347, Accuracy: 8614/10000 (86%)
#
#
# Test set: Average loss: 0.5227, Accuracy: 8639/10000 (86%)
#
#
# Test set: Average loss: 0.5122, Accuracy: 8667/10000 (87%)
#
#
# Test set: Average loss: 0.5044, Accuracy: 8692/10000 (87%)
#
#
# Test set: Average loss: 0.4983, Accuracy: 8674/10000 (87%)
#
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.508393
#
# Test set: Average loss: 0.4919, Accuracy: 8697/10000 (87%)
#
#
# Test set: Average loss: 0.4864, Accuracy: 8676/10000 (87%)
#
#
# Test set: Average loss: 0.4809, Accuracy: 8693/10000 (87%)
#
#
# Test set: Average loss: 0.4776, Accuracy: 8702/10000 (87%)
#
#
# Test set: Average loss: 0.4731, Accuracy: 8708/10000 (87%)
#
#
# Test set: Average loss: 0.4680, Accuracy: 8720/10000 (87%)
#
#
# Test set: Average loss: 0.4621, Accuracy: 8697/10000 (87%)
#
#
# Test set: Average loss: 0.4568, Accuracy: 8713/10000 (87%)
#
#
# Test set: Average loss: 0.4527, Accuracy: 8737/10000 (87%)
#
#
# Test set: Average loss: 0.4473, Accuracy: 8777/10000 (88%)
#
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.466200
#
# Test set: Average loss: 0.4485, Accuracy: 8742/10000 (87%)
#
#
# Test set: Average loss: 0.4413, Accuracy: 8751/10000 (88%)
#
#
# Test set: Average loss: 0.4365, Accuracy: 8798/10000 (88%)
#
#
# Test set: Average loss: 0.4343, Accuracy: 8782/10000 (88%)
#
#
# Test set: Average loss: 0.4329, Accuracy: 8784/10000 (88%)
#
#
# Test set: Average loss: 0.4274, Accuracy: 8777/10000 (88%)
#
#
# Test set: Average loss: 0.4239, Accuracy: 8795/10000 (88%)
#
#
# Test set: Average loss: 0.4201, Accuracy: 8778/10000 (88%)
#
#
# Test set: Average loss: 0.4195, Accuracy: 8797/10000 (88%)
#
#
# Test set: Average loss: 0.4202, Accuracy: 8810/10000 (88%)
#
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.432557
#
# Test set: Average loss: 0.4158, Accuracy: 8818/10000 (88%)
#
#
# Test set: Average loss: 0.4083, Accuracy: 8838/10000 (88%)
#
#
# Test set: Average loss: 0.4061, Accuracy: 8841/10000 (88%)
#
#
# Test set: Average loss: 0.4054, Accuracy: 8832/10000 (88%)
#
#
# Test set: Average loss: 0.4054, Accuracy: 8822/10000 (88%)
#
#
# Test set: Average loss: 0.4034, Accuracy: 8824/10000 (88%)
#
#
# Test set: Average loss: 0.3959, Accuracy: 8855/10000 (89%)
#
#
# Test set: Average loss: 0.4014, Accuracy: 8850/10000 (88%)
#
#
# Test set: Average loss: 0.3939, Accuracy: 8878/10000 (89%)
#
#
# Test set: Average loss: 0.3894, Accuracy: 8879/10000 (89%)
#
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.399734
#
# Test set: Average loss: 0.3849, Accuracy: 8888/10000 (89%)
#
#
# Test set: Average loss: 0.3855, Accuracy: 8877/10000 (89%)
#
#
# Test set: Average loss: 0.3872, Accuracy: 8854/10000 (89%)
#
#
# Test set: Average loss: 0.3828, Accuracy: 8891/10000 (89%)
#
#
# Test set: Average loss: 0.3777, Accuracy: 8900/10000 (89%)
#
#
# Test set: Average loss: 0.3755, Accuracy: 8907/10000 (89%)
#
#
# Test set: Average loss: 0.3757, Accuracy: 8901/10000 (89%)
#
#
# Test set: Average loss: 0.3732, Accuracy: 8895/10000 (89%)
#
#
# Test set: Average loss: 0.3706, Accuracy: 8919/10000 (89%)
#
#
# Test set: Average loss: 0.3718, Accuracy: 8911/10000 (89%)
#
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.417957
#
# Test set: Average loss: 0.3694, Accuracy: 8912/10000 (89%)
#
#
# Test set: Average loss: 0.3686, Accuracy: 8928/10000 (89%)
#
#
# Test set: Average loss: 0.3623, Accuracy: 8939/10000 (89%)
#
#
# Test set: Average loss: 0.3680, Accuracy: 8899/10000 (89%)
#
#
# Test set: Average loss: 0.3613, Accuracy: 8941/10000 (89%)
#
#
# Test set: Average loss: 0.3611, Accuracy: 8934/10000 (89%)
#
#
# Test set: Average loss: 0.3614, Accuracy: 8914/10000 (89%)
#
#
# Test set: Average loss: 0.3596, Accuracy: 8918/10000 (89%)
#
#
# Test set: Average loss: 0.3558, Accuracy: 8964/10000 (90%)
#
#
# Test set: Average loss: 0.3559, Accuracy: 8929/10000 (89%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 3.394461
#
# Test set: Average loss: 0.3980, Accuracy: 8763/10000 (88%)
#
#
# Test set: Average loss: 0.3907, Accuracy: 8850/10000 (88%)
#
#
# Test set: Average loss: 0.3833, Accuracy: 8931/10000 (89%)
#
#
# Test set: Average loss: 0.3832, Accuracy: 8950/10000 (90%)
#
#
# Test set: Average loss: 0.3794, Accuracy: 8945/10000 (89%)
#
#
# Test set: Average loss: 0.3761, Accuracy: 8948/10000 (89%)
#
#
# Test set: Average loss: 0.3708, Accuracy: 8960/10000 (90%)
#
#
# Test set: Average loss: 0.3656, Accuracy: 8990/10000 (90%)
#
#
# Test set: Average loss: 0.3641, Accuracy: 8988/10000 (90%)
#
#
# Test set: Average loss: 0.3588, Accuracy: 8981/10000 (90%)
#
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.377139
#
# Test set: Average loss: 0.3563, Accuracy: 8974/10000 (90%)
#
#
# Test set: Average loss: 0.3514, Accuracy: 8989/10000 (90%)
#
#
# Test set: Average loss: 0.3498, Accuracy: 8994/10000 (90%)
#
#
# Test set: Average loss: 0.3486, Accuracy: 8987/10000 (90%)
#
#
# Test set: Average loss: 0.3478, Accuracy: 8985/10000 (90%)
#
#
# Test set: Average loss: 0.3429, Accuracy: 9017/10000 (90%)
#
#
# Test set: Average loss: 0.3449, Accuracy: 9003/10000 (90%)
#
#
# Test set: Average loss: 0.3408, Accuracy: 9005/10000 (90%)
#
#
# Test set: Average loss: 0.3414, Accuracy: 8985/10000 (90%)
#
#
# Test set: Average loss: 0.3392, Accuracy: 9020/10000 (90%)
#
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.394077
#
# Test set: Average loss: 0.3380, Accuracy: 9004/10000 (90%)
#
#
# Test set: Average loss: 0.3354, Accuracy: 9013/10000 (90%)
#
#
# Test set: Average loss: 0.3358, Accuracy: 9011/10000 (90%)
#
#
# Test set: Average loss: 0.3351, Accuracy: 9020/10000 (90%)
#
#
# Test set: Average loss: 0.3310, Accuracy: 9035/10000 (90%)
#
#
# Test set: Average loss: 0.3276, Accuracy: 9026/10000 (90%)
#
#
# Test set: Average loss: 0.3276, Accuracy: 9023/10000 (90%)
#
#
# Test set: Average loss: 0.3275, Accuracy: 9026/10000 (90%)
#
#
# Test set: Average loss: 0.3256, Accuracy: 9048/10000 (90%)
#
#
# Test set: Average loss: 0.3238, Accuracy: 9047/10000 (90%)
#
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.365462
#
# Test set: Average loss: 0.3230, Accuracy: 9044/10000 (90%)
#
#
# Test set: Average loss: 0.3211, Accuracy: 9062/10000 (91%)
#
#
# Test set: Average loss: 0.3188, Accuracy: 9055/10000 (91%)
#
#
# Test set: Average loss: 0.3188, Accuracy: 9046/10000 (90%)
#
#
# Test set: Average loss: 0.3186, Accuracy: 9062/10000 (91%)
#
#
# Test set: Average loss: 0.3183, Accuracy: 9066/10000 (91%)
#
#
# Test set: Average loss: 0.3172, Accuracy: 9057/10000 (91%)
#
#
# Test set: Average loss: 0.3153, Accuracy: 9045/10000 (90%)
#
#
# Test set: Average loss: 0.3125, Accuracy: 9068/10000 (91%)
#
#
# Test set: Average loss: 0.3130, Accuracy: 9081/10000 (91%)
#
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.334821
#
# Test set: Average loss: 0.3119, Accuracy: 9076/10000 (91%)
#
#
# Test set: Average loss: 0.3089, Accuracy: 9091/10000 (91%)
#
#
# Test set: Average loss: 0.3092, Accuracy: 9082/10000 (91%)
#
#
# Test set: Average loss: 0.3085, Accuracy: 9083/10000 (91%)
#
#
# Test set: Average loss: 0.3079, Accuracy: 9083/10000 (91%)
#
#
# Test set: Average loss: 0.3084, Accuracy: 9069/10000 (91%)
#
#
# Test set: Average loss: 0.3043, Accuracy: 9092/10000 (91%)
#
#
# Test set: Average loss: 0.3064, Accuracy: 9086/10000 (91%)
#
#
# Test set: Average loss: 0.3054, Accuracy: 9077/10000 (91%)
#
#
# Test set: Average loss: 0.3051, Accuracy: 9087/10000 (91%)
#
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.311557
#
# Test set: Average loss: 0.3016, Accuracy: 9087/10000 (91%)
#
#
# Test set: Average loss: 0.3035, Accuracy: 9075/10000 (91%)
#
#
# Test set: Average loss: 0.2982, Accuracy: 9111/10000 (91%)
#
#
# Test set: Average loss: 0.2974, Accuracy: 9118/10000 (91%)
#
#
# Test set: Average loss: 0.2969, Accuracy: 9112/10000 (91%)
#
#
# Test set: Average loss: 0.2982, Accuracy: 9106/10000 (91%)
#
#
# Test set: Average loss: 0.2980, Accuracy: 9094/10000 (91%)
#
#
# Test set: Average loss: 0.2957, Accuracy: 9119/10000 (91%)
#
#
# Test set: Average loss: 0.2938, Accuracy: 9140/10000 (91%)
#
#
# Test set: Average loss: 0.2938, Accuracy: 9119/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.780262
#
# Test set: Average loss: 0.3548, Accuracy: 8888/10000 (89%)
#
#
# Test set: Average loss: 0.3410, Accuracy: 8948/10000 (89%)
#
#
# Test set: Average loss: 0.3199, Accuracy: 9070/10000 (91%)
#
#
# Test set: Average loss: 0.3146, Accuracy: 9101/10000 (91%)
#
#
# Test set: Average loss: 0.3130, Accuracy: 9100/10000 (91%)
#
#
# Test set: Average loss: 0.3109, Accuracy: 9110/10000 (91%)
#
#
# Test set: Average loss: 0.3090, Accuracy: 9130/10000 (91%)
#
#
# Test set: Average loss: 0.3073, Accuracy: 9127/10000 (91%)
#
#
# Test set: Average loss: 0.3051, Accuracy: 9132/10000 (91%)
#
#
# Test set: Average loss: 0.3026, Accuracy: 9131/10000 (91%)
#
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.262222
#
# Test set: Average loss: 0.2999, Accuracy: 9145/10000 (91%)
#
#
# Test set: Average loss: 0.2967, Accuracy: 9130/10000 (91%)
#
#
# Test set: Average loss: 0.2936, Accuracy: 9136/10000 (91%)
#
#
# Test set: Average loss: 0.2924, Accuracy: 9149/10000 (91%)
#
#
# Test set: Average loss: 0.2919, Accuracy: 9150/10000 (92%)
#
#
# Test set: Average loss: 0.2915, Accuracy: 9145/10000 (91%)
#
#
# Test set: Average loss: 0.2888, Accuracy: 9155/10000 (92%)
#
#
# Test set: Average loss: 0.2885, Accuracy: 9159/10000 (92%)
#
#
# Test set: Average loss: 0.2869, Accuracy: 9157/10000 (92%)
#
#
# Test set: Average loss: 0.2865, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.339700
#
# Test set: Average loss: 0.2884, Accuracy: 9133/10000 (91%)
#
#
# Test set: Average loss: 0.2851, Accuracy: 9140/10000 (91%)
#
#
# Test set: Average loss: 0.2845, Accuracy: 9144/10000 (91%)
#
#
# Test set: Average loss: 0.2851, Accuracy: 9135/10000 (91%)
#
#
# Test set: Average loss: 0.2807, Accuracy: 9158/10000 (92%)
#
#
# Test set: Average loss: 0.2806, Accuracy: 9164/10000 (92%)
#
#
# Test set: Average loss: 0.2794, Accuracy: 9173/10000 (92%)
#
#
# Test set: Average loss: 0.2810, Accuracy: 9145/10000 (91%)
#
#
# Test set: Average loss: 0.2802, Accuracy: 9141/10000 (91%)
#
#
# Test set: Average loss: 0.2776, Accuracy: 9160/10000 (92%)
#
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.311816
#
# Test set: Average loss: 0.2757, Accuracy: 9174/10000 (92%)
#
#
# Test set: Average loss: 0.2746, Accuracy: 9190/10000 (92%)
#
#
# Test set: Average loss: 0.2732, Accuracy: 9179/10000 (92%)
#
#
# Test set: Average loss: 0.2763, Accuracy: 9159/10000 (92%)
#
#
# Test set: Average loss: 0.2749, Accuracy: 9175/10000 (92%)
#
#
# Test set: Average loss: 0.2747, Accuracy: 9167/10000 (92%)
#
#
# Test set: Average loss: 0.2716, Accuracy: 9179/10000 (92%)
#
#
# Test set: Average loss: 0.2700, Accuracy: 9177/10000 (92%)
#
#
# Test set: Average loss: 0.2683, Accuracy: 9196/10000 (92%)
#
#
# Test set: Average loss: 0.2683, Accuracy: 9204/10000 (92%)
#
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.235925
#
# Test set: Average loss: 0.2685, Accuracy: 9200/10000 (92%)
#
#
# Test set: Average loss: 0.2679, Accuracy: 9199/10000 (92%)
#
#
# Test set: Average loss: 0.2676, Accuracy: 9192/10000 (92%)
#
#
# Test set: Average loss: 0.2663, Accuracy: 9201/10000 (92%)
#
#
# Test set: Average loss: 0.2648, Accuracy: 9203/10000 (92%)
#
#
# Test set: Average loss: 0.2640, Accuracy: 9213/10000 (92%)
#
#
# Test set: Average loss: 0.2645, Accuracy: 9210/10000 (92%)
#
#
# Test set: Average loss: 0.2632, Accuracy: 9211/10000 (92%)
#
#
# Test set: Average loss: 0.2612, Accuracy: 9211/10000 (92%)
#
#
# Test set: Average loss: 0.2621, Accuracy: 9211/10000 (92%)
#
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.267779
#
# Test set: Average loss: 0.2611, Accuracy: 9215/10000 (92%)
#
#
# Test set: Average loss: 0.2597, Accuracy: 9230/10000 (92%)
#
#
# Test set: Average loss: 0.2601, Accuracy: 9228/10000 (92%)
#
#
# Test set: Average loss: 0.2622, Accuracy: 9221/10000 (92%)
#
#
# Test set: Average loss: 0.2613, Accuracy: 9218/10000 (92%)
#
#
# Test set: Average loss: 0.2628, Accuracy: 9208/10000 (92%)
#
#
# Test set: Average loss: 0.2633, Accuracy: 9208/10000 (92%)
#
#
# Test set: Average loss: 0.2598, Accuracy: 9224/10000 (92%)
#
#
# Test set: Average loss: 0.2557, Accuracy: 9236/10000 (92%)
#
#
# Test set: Average loss: 0.2545, Accuracy: 9235/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.837568
#
# Test set: Average loss: 0.3071, Accuracy: 9041/10000 (90%)
#
#
# Test set: Average loss: 0.3143, Accuracy: 9016/10000 (90%)
#
#
# Test set: Average loss: 0.2964, Accuracy: 9118/10000 (91%)
#
#
# Test set: Average loss: 0.2838, Accuracy: 9185/10000 (92%)
#
#
# Test set: Average loss: 0.2792, Accuracy: 9242/10000 (92%)
#
#
# Test set: Average loss: 0.2776, Accuracy: 9242/10000 (92%)
#
#
# Test set: Average loss: 0.2749, Accuracy: 9225/10000 (92%)
#
#
# Test set: Average loss: 0.2705, Accuracy: 9229/10000 (92%)
#
#
# Test set: Average loss: 0.2680, Accuracy: 9228/10000 (92%)
#
#
# Test set: Average loss: 0.2664, Accuracy: 9228/10000 (92%)
#
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 0.302757
#
# Test set: Average loss: 0.2646, Accuracy: 9230/10000 (92%)
#
#
# Test set: Average loss: 0.2625, Accuracy: 9251/10000 (93%)
#
#
# Test set: Average loss: 0.2619, Accuracy: 9257/10000 (93%)
#
#
# Test set: Average loss: 0.2615, Accuracy: 9268/10000 (93%)
#
#
# Test set: Average loss: 0.2569, Accuracy: 9268/10000 (93%)
#
#
# Test set: Average loss: 0.2550, Accuracy: 9261/10000 (93%)
#
#
# Test set: Average loss: 0.2557, Accuracy: 9237/10000 (92%)
#
#
# Test set: Average loss: 0.2546, Accuracy: 9245/10000 (92%)
#
#
# Test set: Average loss: 0.2530, Accuracy: 9262/10000 (93%)
#
#
# Test set: Average loss: 0.2530, Accuracy: 9251/10000 (93%)
#
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 0.276726
#
# Test set: Average loss: 0.2523, Accuracy: 9253/10000 (93%)
#
#
# Test set: Average loss: 0.2508, Accuracy: 9261/10000 (93%)
#
#
# Test set: Average loss: 0.2493, Accuracy: 9277/10000 (93%)
#
#
# Test set: Average loss: 0.2496, Accuracy: 9278/10000 (93%)
#
#
# Test set: Average loss: 0.2485, Accuracy: 9266/10000 (93%)
#
#
# Test set: Average loss: 0.2478, Accuracy: 9260/10000 (93%)
#
#
# Test set: Average loss: 0.2473, Accuracy: 9269/10000 (93%)
#
#
# Test set: Average loss: 0.2461, Accuracy: 9274/10000 (93%)
#
#
# Test set: Average loss: 0.2445, Accuracy: 9287/10000 (93%)
#
#
# Test set: Average loss: 0.2453, Accuracy: 9274/10000 (93%)
#
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 0.228336
#
# Test set: Average loss: 0.2446, Accuracy: 9270/10000 (93%)
#
#
# Test set: Average loss: 0.2437, Accuracy: 9287/10000 (93%)
#
#
# Test set: Average loss: 0.2435, Accuracy: 9275/10000 (93%)
#
#
# Test set: Average loss: 0.2431, Accuracy: 9271/10000 (93%)
#
#
# Test set: Average loss: 0.2458, Accuracy: 9272/10000 (93%)
#
#
# Test set: Average loss: 0.2432, Accuracy: 9281/10000 (93%)
#
#
# Test set: Average loss: 0.2415, Accuracy: 9286/10000 (93%)
#
#
# Test set: Average loss: 0.2408, Accuracy: 9289/10000 (93%)
#
#
# Test set: Average loss: 0.2418, Accuracy: 9272/10000 (93%)
#
#
# Test set: Average loss: 0.2397, Accuracy: 9293/10000 (93%)
#
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 0.225290
#
# Test set: Average loss: 0.2375, Accuracy: 9290/10000 (93%)
#
#
# Test set: Average loss: 0.2364, Accuracy: 9290/10000 (93%)
#
#
# Test set: Average loss: 0.2370, Accuracy: 9289/10000 (93%)
#
#
# Test set: Average loss: 0.2354, Accuracy: 9306/10000 (93%)
#
#
# Test set: Average loss: 0.2354, Accuracy: 9309/10000 (93%)
#
#
# Test set: Average loss: 0.2345, Accuracy: 9301/10000 (93%)
#
#
# Test set: Average loss: 0.2356, Accuracy: 9296/10000 (93%)
#
#
# Test set: Average loss: 0.2365, Accuracy: 9293/10000 (93%)
#
#
# Test set: Average loss: 0.2341, Accuracy: 9305/10000 (93%)
#
#
# Test set: Average loss: 0.2344, Accuracy: 9318/10000 (93%)
#
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 0.259003
#
# Test set: Average loss: 0.2349, Accuracy: 9291/10000 (93%)
#
#
# Test set: Average loss: 0.2322, Accuracy: 9309/10000 (93%)
#
#
# Test set: Average loss: 0.2317, Accuracy: 9304/10000 (93%)
#
#
# Test set: Average loss: 0.2332, Accuracy: 9308/10000 (93%)
#
#
# Test set: Average loss: 0.2291, Accuracy: 9321/10000 (93%)
#
#
# Test set: Average loss: 0.2301, Accuracy: 9322/10000 (93%)
#
#
# Test set: Average loss: 0.2280, Accuracy: 9341/10000 (93%)
#
#
# Test set: Average loss: 0.2275, Accuracy: 9332/10000 (93%)
#
#
# Test set: Average loss: 0.2277, Accuracy: 9332/10000 (93%)
#
#
# Test set: Average loss: 0.2307, Accuracy: 9310/10000 (93%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.375690
#
# Test set: Average loss: 0.2592, Accuracy: 9204/10000 (92%)
#
#
# Test set: Average loss: 0.2687, Accuracy: 9199/10000 (92%)
#
#
# Test set: Average loss: 0.2588, Accuracy: 9244/10000 (92%)
#
#
# Test set: Average loss: 0.2503, Accuracy: 9297/10000 (93%)
#
#
# Test set: Average loss: 0.2499, Accuracy: 9297/10000 (93%)
#
#
# Test set: Average loss: 0.2472, Accuracy: 9315/10000 (93%)
#
#
# Test set: Average loss: 0.2430, Accuracy: 9323/10000 (93%)
#
#
# Test set: Average loss: 0.2407, Accuracy: 9320/10000 (93%)
#
#
# Test set: Average loss: 0.2388, Accuracy: 9321/10000 (93%)
#
#
# Test set: Average loss: 0.2364, Accuracy: 9324/10000 (93%)
#
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 0.236900
#
# Test set: Average loss: 0.2355, Accuracy: 9322/10000 (93%)
#
#
# Test set: Average loss: 0.2337, Accuracy: 9329/10000 (93%)
#
#
# Test set: Average loss: 0.2337, Accuracy: 9327/10000 (93%)
#
#
# Test set: Average loss: 0.2318, Accuracy: 9323/10000 (93%)
#
#
# Test set: Average loss: 0.2310, Accuracy: 9321/10000 (93%)
#
#
# Test set: Average loss: 0.2286, Accuracy: 9325/10000 (93%)
#
#
# Test set: Average loss: 0.2271, Accuracy: 9328/10000 (93%)
#
#
# Test set: Average loss: 0.2277, Accuracy: 9335/10000 (93%)
#
#
# Test set: Average loss: 0.2294, Accuracy: 9325/10000 (93%)
#
#
# Test set: Average loss: 0.2272, Accuracy: 9331/10000 (93%)
#
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 0.251097
#
# Test set: Average loss: 0.2258, Accuracy: 9323/10000 (93%)
#
#
# Test set: Average loss: 0.2264, Accuracy: 9325/10000 (93%)
#
#
# Test set: Average loss: 0.2236, Accuracy: 9340/10000 (93%)
#
#
# Test set: Average loss: 0.2224, Accuracy: 9345/10000 (93%)
#
#
# Test set: Average loss: 0.2210, Accuracy: 9356/10000 (94%)
#
#
# Test set: Average loss: 0.2206, Accuracy: 9356/10000 (94%)
#
#
# Test set: Average loss: 0.2201, Accuracy: 9343/10000 (93%)
#
#
# Test set: Average loss: 0.2195, Accuracy: 9365/10000 (94%)
#
#
# Test set: Average loss: 0.2208, Accuracy: 9339/10000 (93%)
#
#
# Test set: Average loss: 0.2225, Accuracy: 9332/10000 (93%)
#
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 0.233526
#
# Test set: Average loss: 0.2214, Accuracy: 9339/10000 (93%)
#
#
# Test set: Average loss: 0.2182, Accuracy: 9359/10000 (94%)
#
#
# Test set: Average loss: 0.2185, Accuracy: 9347/10000 (93%)
#
#
# Test set: Average loss: 0.2183, Accuracy: 9361/10000 (94%)
#
#
# Test set: Average loss: 0.2174, Accuracy: 9363/10000 (94%)
#
#
# Test set: Average loss: 0.2176, Accuracy: 9374/10000 (94%)
#
#
# Test set: Average loss: 0.2159, Accuracy: 9373/10000 (94%)
#
#
# Test set: Average loss: 0.2149, Accuracy: 9371/10000 (94%)
#
#
# Test set: Average loss: 0.2144, Accuracy: 9353/10000 (94%)
#
#
# Test set: Average loss: 0.2133, Accuracy: 9370/10000 (94%)
#
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 0.256543
#
# Test set: Average loss: 0.2130, Accuracy: 9375/10000 (94%)
#
#
# Test set: Average loss: 0.2139, Accuracy: 9365/10000 (94%)
#
#
# Test set: Average loss: 0.2143, Accuracy: 9363/10000 (94%)
#
#
# Test set: Average loss: 0.2168, Accuracy: 9353/10000 (94%)
#
#
# Test set: Average loss: 0.2128, Accuracy: 9373/10000 (94%)
#
#
# Test set: Average loss: 0.2123, Accuracy: 9377/10000 (94%)
#
#
# Test set: Average loss: 0.2122, Accuracy: 9377/10000 (94%)
#
#
# Test set: Average loss: 0.2104, Accuracy: 9382/10000 (94%)
#
#
# Test set: Average loss: 0.2108, Accuracy: 9375/10000 (94%)
#
#
# Test set: Average loss: 0.2125, Accuracy: 9350/10000 (94%)
#
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 0.230152
#
# Test set: Average loss: 0.2108, Accuracy: 9367/10000 (94%)
#
#
# Test set: Average loss: 0.2108, Accuracy: 9352/10000 (94%)
#
#
# Test set: Average loss: 0.2123, Accuracy: 9356/10000 (94%)
#
#
# Test set: Average loss: 0.2111, Accuracy: 9382/10000 (94%)
#
#
# Test set: Average loss: 0.2102, Accuracy: 9377/10000 (94%)
#
#
# Test set: Average loss: 0.2092, Accuracy: 9391/10000 (94%)
#
#
# Test set: Average loss: 0.2088, Accuracy: 9411/10000 (94%)
#
#
# Test set: Average loss: 0.2068, Accuracy: 9403/10000 (94%)
#
#
# Test set: Average loss: 0.2067, Accuracy: 9391/10000 (94%)
#
#
# Test set: Average loss: 0.2056, Accuracy: 9391/10000 (94%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.181460
#
# Test set: Average loss: 0.2607, Accuracy: 9189/10000 (92%)
#
#
# Test set: Average loss: 0.2646, Accuracy: 9182/10000 (92%)
#
#
# Test set: Average loss: 0.2450, Accuracy: 9264/10000 (93%)
#
#
# Test set: Average loss: 0.2297, Accuracy: 9356/10000 (94%)
#
#
# Test set: Average loss: 0.2231, Accuracy: 9383/10000 (94%)
#
#
# Test set: Average loss: 0.2217, Accuracy: 9389/10000 (94%)
#
#
# Test set: Average loss: 0.2220, Accuracy: 9374/10000 (94%)
#
#
# Test set: Average loss: 0.2185, Accuracy: 9390/10000 (94%)
#
#
# Test set: Average loss: 0.2171, Accuracy: 9390/10000 (94%)
#
#
# Test set: Average loss: 0.2161, Accuracy: 9386/10000 (94%)
#
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 0.215742
#
# Test set: Average loss: 0.2138, Accuracy: 9387/10000 (94%)
#
#
# Test set: Average loss: 0.2123, Accuracy: 9387/10000 (94%)
#
#
# Test set: Average loss: 0.2112, Accuracy: 9394/10000 (94%)
#
#
# Test set: Average loss: 0.2097, Accuracy: 9400/10000 (94%)
#
#
# Test set: Average loss: 0.2090, Accuracy: 9395/10000 (94%)
#
#
# Test set: Average loss: 0.2084, Accuracy: 9403/10000 (94%)
#
#
# Test set: Average loss: 0.2080, Accuracy: 9404/10000 (94%)
#
#
# Test set: Average loss: 0.2080, Accuracy: 9403/10000 (94%)
#
#
# Test set: Average loss: 0.2067, Accuracy: 9410/10000 (94%)
#
#
# Test set: Average loss: 0.2056, Accuracy: 9408/10000 (94%)
#
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 0.233848
#
# Test set: Average loss: 0.2066, Accuracy: 9389/10000 (94%)
#
#
# Test set: Average loss: 0.2052, Accuracy: 9393/10000 (94%)
#
#
# Test set: Average loss: 0.2034, Accuracy: 9411/10000 (94%)
#
#
# Test set: Average loss: 0.2049, Accuracy: 9408/10000 (94%)
#
#
# Test set: Average loss: 0.2045, Accuracy: 9405/10000 (94%)
#
#
# Test set: Average loss: 0.2030, Accuracy: 9408/10000 (94%)
#
#
# Test set: Average loss: 0.2027, Accuracy: 9409/10000 (94%)
#
#
# Test set: Average loss: 0.2040, Accuracy: 9396/10000 (94%)
#
#
# Test set: Average loss: 0.2014, Accuracy: 9405/10000 (94%)
#
#
# Test set: Average loss: 0.2002, Accuracy: 9409/10000 (94%)
#
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 0.225434
#
# Test set: Average loss: 0.1986, Accuracy: 9424/10000 (94%)
#
#
# Test set: Average loss: 0.1984, Accuracy: 9423/10000 (94%)
#
#
# Test set: Average loss: 0.1984, Accuracy: 9429/10000 (94%)
#
#
# Test set: Average loss: 0.1992, Accuracy: 9415/10000 (94%)
#
#
# Test set: Average loss: 0.1997, Accuracy: 9413/10000 (94%)
#
#
# Test set: Average loss: 0.1972, Accuracy: 9423/10000 (94%)
#
#
# Test set: Average loss: 0.1975, Accuracy: 9418/10000 (94%)
#
#
# Test set: Average loss: 0.1983, Accuracy: 9416/10000 (94%)
#
#
# Test set: Average loss: 0.1973, Accuracy: 9414/10000 (94%)
#
#
# Test set: Average loss: 0.1971, Accuracy: 9406/10000 (94%)
#
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 0.246390
#
# Test set: Average loss: 0.1960, Accuracy: 9422/10000 (94%)
#
#
# Test set: Average loss: 0.1955, Accuracy: 9429/10000 (94%)
#
#
# Test set: Average loss: 0.1945, Accuracy: 9441/10000 (94%)
#
#
# Test set: Average loss: 0.1937, Accuracy: 9441/10000 (94%)
#
#
# Test set: Average loss: 0.1940, Accuracy: 9429/10000 (94%)
#
#
# Test set: Average loss: 0.1945, Accuracy: 9423/10000 (94%)
#
#
# Test set: Average loss: 0.1938, Accuracy: 9429/10000 (94%)
#
#
# Test set: Average loss: 0.1926, Accuracy: 9440/10000 (94%)
#
#
# Test set: Average loss: 0.1919, Accuracy: 9433/10000 (94%)
#
#
# Test set: Average loss: 0.1926, Accuracy: 9433/10000 (94%)
#
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 0.213175
#
# Test set: Average loss: 0.1918, Accuracy: 9439/10000 (94%)
#
#
# Test set: Average loss: 0.1907, Accuracy: 9439/10000 (94%)
#
#
# Test set: Average loss: 0.1912, Accuracy: 9445/10000 (94%)
#
#
# Test set: Average loss: 0.1907, Accuracy: 9449/10000 (94%)
#
#
# Test set: Average loss: 0.1915, Accuracy: 9448/10000 (94%)
#
#
# Test set: Average loss: 0.1915, Accuracy: 9430/10000 (94%)
#
#
# Test set: Average loss: 0.1911, Accuracy: 9424/10000 (94%)
#
#
# Test set: Average loss: 0.1894, Accuracy: 9424/10000 (94%)
#
#
# Test set: Average loss: 0.1880, Accuracy: 9444/10000 (94%)
#
#
# Test set: Average loss: 0.1871, Accuracy: 9450/10000 (94%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 2.006928
#
# Test set: Average loss: 0.2090, Accuracy: 9382/10000 (94%)
#
#
# Test set: Average loss: 0.2193, Accuracy: 9348/10000 (93%)
#
#
# Test set: Average loss: 0.2131, Accuracy: 9381/10000 (94%)
#
#
# Test set: Average loss: 0.2078, Accuracy: 9404/10000 (94%)
#
#
# Test set: Average loss: 0.2033, Accuracy: 9434/10000 (94%)
#
#
# Test set: Average loss: 0.2005, Accuracy: 9450/10000 (94%)
#
#
# Test set: Average loss: 0.2000, Accuracy: 9451/10000 (95%)
#
#
# Test set: Average loss: 0.1988, Accuracy: 9449/10000 (94%)
#
#
# Test set: Average loss: 0.1969, Accuracy: 9448/10000 (94%)
#
#
# Test set: Average loss: 0.1952, Accuracy: 9447/10000 (94%)
#
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 0.207812
#
# Test set: Average loss: 0.1932, Accuracy: 9459/10000 (95%)
#
#
# Test set: Average loss: 0.1935, Accuracy: 9457/10000 (95%)
#
#
# Test set: Average loss: 0.1918, Accuracy: 9455/10000 (95%)
#
#
# Test set: Average loss: 0.1913, Accuracy: 9447/10000 (94%)
#
#
# Test set: Average loss: 0.1914, Accuracy: 9451/10000 (95%)
#
#
# Test set: Average loss: 0.1913, Accuracy: 9449/10000 (94%)
#
#
# Test set: Average loss: 0.1907, Accuracy: 9460/10000 (95%)
#
#
# Test set: Average loss: 0.1904, Accuracy: 9457/10000 (95%)
#
#
# Test set: Average loss: 0.1917, Accuracy: 9442/10000 (94%)
#
#
# Test set: Average loss: 0.1896, Accuracy: 9449/10000 (94%)
#
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 0.193151
#
# Test set: Average loss: 0.1884, Accuracy: 9441/10000 (94%)
#
#
# Test set: Average loss: 0.1872, Accuracy: 9460/10000 (95%)
#
#
# Test set: Average loss: 0.1872, Accuracy: 9456/10000 (95%)
#
#
# Test set: Average loss: 0.1864, Accuracy: 9464/10000 (95%)
#
#
# Test set: Average loss: 0.1871, Accuracy: 9451/10000 (95%)
#
#
# Test set: Average loss: 0.1868, Accuracy: 9454/10000 (95%)
#
#
# Test set: Average loss: 0.1859, Accuracy: 9459/10000 (95%)
#
#
# Test set: Average loss: 0.1843, Accuracy: 9480/10000 (95%)
#
#
# Test set: Average loss: 0.1847, Accuracy: 9464/10000 (95%)
#
#
# Test set: Average loss: 0.1850, Accuracy: 9459/10000 (95%)
#
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 0.198799
#
# Test set: Average loss: 0.1834, Accuracy: 9465/10000 (95%)
#
#
# Test set: Average loss: 0.1831, Accuracy: 9474/10000 (95%)
#
#
# Test set: Average loss: 0.1821, Accuracy: 9473/10000 (95%)
#
#
# Test set: Average loss: 0.1816, Accuracy: 9464/10000 (95%)
#
#
# Test set: Average loss: 0.1813, Accuracy: 9475/10000 (95%)
#
#
# Test set: Average loss: 0.1819, Accuracy: 9468/10000 (95%)
#
#
# Test set: Average loss: 0.1831, Accuracy: 9468/10000 (95%)
#
#
# Test set: Average loss: 0.1810, Accuracy: 9476/10000 (95%)
#
#
# Test set: Average loss: 0.1802, Accuracy: 9466/10000 (95%)
#
#
# Test set: Average loss: 0.1792, Accuracy: 9474/10000 (95%)
#
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 0.213426
#
# Test set: Average loss: 0.1790, Accuracy: 9473/10000 (95%)
#
#
# Test set: Average loss: 0.1788, Accuracy: 9472/10000 (95%)
#
#
# Test set: Average loss: 0.1787, Accuracy: 9467/10000 (95%)
#
#
# Test set: Average loss: 0.1792, Accuracy: 9478/10000 (95%)
#
#
# Test set: Average loss: 0.1784, Accuracy: 9484/10000 (95%)
#
#
# Test set: Average loss: 0.1785, Accuracy: 9473/10000 (95%)
#
#
# Test set: Average loss: 0.1795, Accuracy: 9465/10000 (95%)
#
#
# Test set: Average loss: 0.1782, Accuracy: 9479/10000 (95%)
#
#
# Test set: Average loss: 0.1780, Accuracy: 9486/10000 (95%)
#
#
# Test set: Average loss: 0.1789, Accuracy: 9476/10000 (95%)
#
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 0.197534
#
# Test set: Average loss: 0.1765, Accuracy: 9479/10000 (95%)
#
#
# Test set: Average loss: 0.1761, Accuracy: 9485/10000 (95%)
#
#
# Test set: Average loss: 0.1763, Accuracy: 9492/10000 (95%)
#
#
# Test set: Average loss: 0.1761, Accuracy: 9486/10000 (95%)
#
#
# Test set: Average loss: 0.1762, Accuracy: 9484/10000 (95%)
#
#
# Test set: Average loss: 0.1763, Accuracy: 9490/10000 (95%)
#
#
# Test set: Average loss: 0.1746, Accuracy: 9500/10000 (95%)
#
#
# Test set: Average loss: 0.1743, Accuracy: 9486/10000 (95%)
#
#
# Test set: Average loss: 0.1754, Accuracy: 9486/10000 (95%)
#
#
# Test set: Average loss: 0.1757, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 2.129700
#
# Test set: Average loss: 0.2114, Accuracy: 9343/10000 (93%)
#
#
# Test set: Average loss: 0.2189, Accuracy: 9334/10000 (93%)
#
#
# Test set: Average loss: 0.2055, Accuracy: 9400/10000 (94%)
#
#
# Test set: Average loss: 0.1945, Accuracy: 9441/10000 (94%)
#
#
# Test set: Average loss: 0.1900, Accuracy: 9474/10000 (95%)
#
#
# Test set: Average loss: 0.1885, Accuracy: 9485/10000 (95%)
#
#
# Test set: Average loss: 0.1866, Accuracy: 9491/10000 (95%)
#
#
# Test set: Average loss: 0.1847, Accuracy: 9495/10000 (95%)
#
#
# Test set: Average loss: 0.1848, Accuracy: 9486/10000 (95%)
#
#
# Test set: Average loss: 0.1835, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 0.175566
#
# Test set: Average loss: 0.1822, Accuracy: 9494/10000 (95%)
#
#
# Test set: Average loss: 0.1814, Accuracy: 9489/10000 (95%)
#
#
# Test set: Average loss: 0.1799, Accuracy: 9488/10000 (95%)
#
#
# Test set: Average loss: 0.1792, Accuracy: 9497/10000 (95%)
#
#
# Test set: Average loss: 0.1796, Accuracy: 9480/10000 (95%)
#
#
# Test set: Average loss: 0.1792, Accuracy: 9491/10000 (95%)
#
#
# Test set: Average loss: 0.1778, Accuracy: 9493/10000 (95%)
#
#
# Test set: Average loss: 0.1769, Accuracy: 9489/10000 (95%)
#
#
# Test set: Average loss: 0.1752, Accuracy: 9506/10000 (95%)
#
#
# Test set: Average loss: 0.1746, Accuracy: 9502/10000 (95%)
#
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 0.149247
#
# Test set: Average loss: 0.1742, Accuracy: 9494/10000 (95%)
#
#
# Test set: Average loss: 0.1736, Accuracy: 9500/10000 (95%)
#
#
# Test set: Average loss: 0.1736, Accuracy: 9504/10000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 9503/10000 (95%)
#
#
# Test set: Average loss: 0.1726, Accuracy: 9503/10000 (95%)
#
#
# Test set: Average loss: 0.1730, Accuracy: 9502/10000 (95%)
#
#
# Test set: Average loss: 0.1726, Accuracy: 9502/10000 (95%)
#
#
# Test set: Average loss: 0.1721, Accuracy: 9500/10000 (95%)
#
#
# Test set: Average loss: 0.1715, Accuracy: 9506/10000 (95%)
#
#
# Test set: Average loss: 0.1707, Accuracy: 9507/10000 (95%)
#
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 0.210732
#
# Test set: Average loss: 0.1702, Accuracy: 9507/10000 (95%)
#
#
# Test set: Average loss: 0.1700, Accuracy: 9506/10000 (95%)
#
#
# Test set: Average loss: 0.1697, Accuracy: 9512/10000 (95%)
#
#
# Test set: Average loss: 0.1697, Accuracy: 9512/10000 (95%)
#
#
# Test set: Average loss: 0.1690, Accuracy: 9516/10000 (95%)
#
#
# Test set: Average loss: 0.1685, Accuracy: 9510/10000 (95%)
#
#
# Test set: Average loss: 0.1682, Accuracy: 9511/10000 (95%)
#
#
# Test set: Average loss: 0.1676, Accuracy: 9518/10000 (95%)
#
#
# Test set: Average loss: 0.1682, Accuracy: 9511/10000 (95%)
#
#
# Test set: Average loss: 0.1678, Accuracy: 9512/10000 (95%)
#
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 0.195230
#
# Test set: Average loss: 0.1672, Accuracy: 9525/10000 (95%)
#
#
# Test set: Average loss: 0.1674, Accuracy: 9511/10000 (95%)
#
#
# Test set: Average loss: 0.1678, Accuracy: 9521/10000 (95%)
#
#
# Test set: Average loss: 0.1677, Accuracy: 9519/10000 (95%)
#
#
# Test set: Average loss: 0.1672, Accuracy: 9520/10000 (95%)
#
#
# Test set: Average loss: 0.1670, Accuracy: 9513/10000 (95%)
#
#
# Test set: Average loss: 0.1664, Accuracy: 9512/10000 (95%)
#
#
# Test set: Average loss: 0.1665, Accuracy: 9499/10000 (95%)
#
#
# Test set: Average loss: 0.1672, Accuracy: 9504/10000 (95%)
#
#
# Test set: Average loss: 0.1664, Accuracy: 9514/10000 (95%)
#
# Train Epoch: 10 [50000/60000 (83%)]	Loss: 0.166198
#
# Test set: Average loss: 0.1664, Accuracy: 9517/10000 (95%)
#
#
# Test set: Average loss: 0.1666, Accuracy: 9525/10000 (95%)
#
#
# Test set: Average loss: 0.1666, Accuracy: 9504/10000 (95%)
#
#
# Test set: Average loss: 0.1649, Accuracy: 9515/10000 (95%)
#
#
# Test set: Average loss: 0.1630, Accuracy: 9524/10000 (95%)
#
#
# Test set: Average loss: 0.1625, Accuracy: 9527/10000 (95%)
#
#
# Test set: Average loss: 0.1629, Accuracy: 9513/10000 (95%)
#
#
# Test set: Average loss: 0.1628, Accuracy: 9513/10000 (95%)
#
#
# Test set: Average loss: 0.1623, Accuracy: 9516/10000 (95%)
#
#
# Test set: Average loss: 0.1617, Accuracy: 9522/10000 (95%)
